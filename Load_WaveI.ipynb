# %%
import pandas as pd
# The data is publicly available, on https://dataverse.unc.edu/dataset.xhtml?persistentId=doi:10.15139/S3/11900&version=3.3
# I choose not to put the data in this public repo for licensing reasons.
data_dir = "/home/llinfeng/Dropbox/Research/Data/AddHealth/WaveI/"

# %% [markdown]
# Supposedly, the WaveI data with n=55208 is under restricted access. Yet, it takes $1,000 to buy into the contract for restricted access.

# %%
df_net = pd.read_sas(data_dir + "w1network.sas7bdat")
df_net.filter(like="EGO").shape

# Note, problem here: there should 55208, by Table 1 in Bramoullé et. al. 2009. Only 6504 here.
# Out:
# ...
# /home/llinfeng/.local/lib/python3.9/site-packages/pandas/io/sas/sas7bdat.py:800: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   rslt[name] = self._byte_chunk[jb, :].view(dtype=self.byte_order + "d")
# (6504, 0)

# %%
df_net = pd.read_sas(data_dir + "w1network.sas7bdat")
df_net.filter(like="EGO").shape
# Out:
# ...
# /home/llinfeng/.local/lib/python3.9/site-packages/pandas/io/sas/sas7bdat.py:800: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   rslt[name] = self._byte_chunk[jb, :].view(dtype=self.byte_order + "d")
# (6504, 0)

# %%
df_net
# Out:
#               AID   SIZE  IDGX2  ODGX2  NOUTNOM  TAB113  BCENT10X  REACH  \
# 0     b'57100270'    NaN    NaN    NaN      NaN     NaN       NaN    NaN
# 1     b'57101310'    NaN    NaN    NaN      NaN     NaN       NaN    NaN
# 2     b'57103171'    NaN    NaN    NaN      NaN     NaN       NaN    NaN
# 3     b'57103869'    NaN    NaN    NaN      NaN     NaN       NaN    NaN
# 4     b'57104553'    NaN    NaN    NaN      NaN     NaN       NaN    NaN
# ...           ...    ...    ...    ...      ...     ...       ...    ...
# 6499  b'99719930'   93.0    2.0    6.0      4.0     0.0  0.969996   79.0
# 6500  b'99719939'   93.0    3.0    3.0      1.0     0.0  0.469026   79.0
# 6501  b'99719970'  191.0    3.0    2.0      2.0     0.0  0.263245  148.0
# 6502  b'99719976'    NaN    NaN    NaN      NaN     NaN       NaN    NaN
# 6503  b'99719978'    NaN    NaN    NaN      NaN     NaN       NaN    NaN
#
#       REACH3   IGDMEAN  ...  SS312  SEG1RCE5    SRCE51    SRCE52    SRCE53  \
# ...

# %%
pd.read_sas(data_dir + 'w1network_fmt_data.sas7bdat')
# Out:
#         FMTNAME                START                  END  \
# 0   b'BFFRECBF'  b'               0'  b'               0'
# 1   b'BFFRECBF'  b'               1'  b'               1'
# 2   b'BFFRECIP'  b'               0'  b'               0'
# 3   b'BFFRECIP'  b'               1'  b'               1'
# 4   b'BMFRECBF'  b'               0'  b'               0'
# 5   b'BMFRECBF'  b'               1'  b'               1'
# 6   b'BMFRECIP'  b'               0'  b'               0'
# 7   b'BMFRECIP'  b'               1'  b'               1'
# 8    b'HAVEBFF'  b'               0'  b'               0'
# 9    b'HAVEBFF'  b'               1'  b'               1'
# 10   b'HAVEBMF'  b'               0'  b'               0'
# 11   b'HAVEBMF'  b'               1'  b'               1'
#
#                                                 LABEL  MIN   MAX  DEFAULT  \
# 0   b"(0) Ego's female best friend didn't reciproc...  1.0  62.0     62.0
# ...

# %%
pd.read_sas(data_dir + 'w1network_format.sas7bcat')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_28143/21246518.py in <module>
# ----> 1 pd.read_sas(data_dir + 'w1network_format.sas7bcat')
#
# ~/.local/lib/python3.9/site-packages/pandas/io/sas/sasreader.py in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator)
#     131             format = "sas7bdat"
#     132         else:
# --> 133             raise ValueError("unable to infer format of SAS file")
#     134
#     135     reader: ReaderBase
#
# ValueError: unable to infer format of SAS file

# %%
pd.read_sas(data_dir + 'w1network_fmt_data.sas7bdat')
# Out:
#         FMTNAME                START                  END  \
# 0   b'BFFRECBF'  b'               0'  b'               0'
# 1   b'BFFRECBF'  b'               1'  b'               1'
# 2   b'BFFRECIP'  b'               0'  b'               0'
# 3   b'BFFRECIP'  b'               1'  b'               1'
# 4   b'BMFRECBF'  b'               0'  b'               0'
# 5   b'BMFRECBF'  b'               1'  b'               1'
# 6   b'BMFRECIP'  b'               0'  b'               0'
# 7   b'BMFRECIP'  b'               1'  b'               1'
# 8    b'HAVEBFF'  b'               0'  b'               0'
# 9    b'HAVEBFF'  b'               1'  b'               1'
# 10   b'HAVEBMF'  b'               0'  b'               0'
# 11   b'HAVEBMF'  b'               1'  b'               1'
#
#                                                 LABEL  MIN   MAX  DEFAULT  \
# 0   b"(0) Ego's female best friend didn't reciproc...  1.0  62.0     62.0
# ...
